140093.718750,498305\n2016-06-08,141800.000000,145000.000000,141600.000000,144400.000000,143066.031250,556190\n2016-06-09,146200.000000,146600.000000,142400.000000,144000.000000,142669.703125,672840\n2016-06-10,146200.000000,146600.000000,143400.000000,144000.000000,142669.703125,475005\n2016-06-13,142800.000000,142800.000000,137200.000000,139400.000000,138112.203125,800590\n2016-06-14,137800.000000,140400.000000,135800.000000,139400.000000,138112.203125,654895\n2016-06-15,140800.000000,141800.000000,138400.000000,139400.000000,138112.203125,352325\n2016-06-16,138200.000000,140200.000000,138200.000000,140200.000000,138904.812500,299220\n2016-06-17,140200.000000,140400.000000,137600.000000,137800.000000,136526.984375,367800\n2016-06-20,139400.000000,139400.000000,136800.000000,138400.000000,137121.453125,307550\n2016-06-21,138800.000000,139600.000000,137600.000000,139400.000000,138112.203125,307700\n2016-06-22,139800.000000,146000.000000,139800.000000,146000.000000,144651.250000,1005435\n2016-06-23,146600.000000,152000.000000,146400.000000,149400.000000,148019.828125,1130610\n2016-06-24,149000.000000,151800.000000,144200.000000,147800.000000,146434.625000,867905\n2016-06-27,145600.000 ...

# %%
data = pd.read_csv('naver.csv')
data
# Out:
#             Date      Open      High  ...     Close      Adj Close    Volume
# 0     2016-04-21  132000.0  133400.0  ...  133400.0  132167.656250  412070.0
# 1     2016-04-22  132000.0  133000.0  ...  132600.0  131375.031250  194870.0
# 2     2016-04-25  132400.0  133000.0  ...  132400.0  131176.875000  355620.0
# 3     2016-04-26  132600.0  134400.0  ...  130800.0  129591.664063  789600.0
# 4     2016-04-27  129600.0  133000.0  ...  133000.0  131771.343750  403340.0
# ...          ...       ...       ...  ...       ...            ...       ...
# 1222  2021-04-15  391500.0  398500.0  ...  391000.0  391000.000000  889538.0
# 1223  2021-04-16  394500.0  395000.0  ...  391500.0  391500.000000  423962.0
# 1224  2021-04-19  391500.0  393500.0  ...  390000.0  390000.000000  449064.0
# 1225  2021-04-20  389000.0  391500.0  ...  391000.0  391000.000000  417892.0
# 1226  2021-04-21  389000.0  389000.0  ...  380500.0  380500.000000  830392.0
#
# [1227 rows x 7 columns]

# %% [markdown]
# - Open(시가): 주식에서 처음 거래된 가격(우리나라 오전 9시)
# - Close(종가): 당일 맨 마지막 거래가 체결된 가격(우리나라 오후 3시)
# - High/Low: 최고거래가/최저거래가
# - Adj Close: 수정 종가라는 뜻으로 분할, 배당, 배분, 신주 발생이 된 경우를 고려해 주식 가격을 조정(adjustment)해둔 가격
# - Volume: 주식거래량

# %% [markdown]
# # **Data preprocessing**

# %%
# 데이터 개수 파악
data.count()
# Out:
# Date         1227
# Open         1222
# High         1222
# Low          1222
# Close        1222
# Adj Close    1222
# Volume       1222
# dtype: int64

# %%
# 결측치 개수 파악
data.isnull().sum()
# Out:
# Date         0
# Open         5
# High         5
# Low          5
# Close        5
# Adj Close    5
# Volume       5
# dtype: int64

# %%
# 결측치가 있는 행 제거
data = data.dropna()
data.count()
# Out:
# Date         1222
# Open         1222
# High         1222
# Low          1222
# Close        1222
# Adj Close    1222
# Volume       1222
# dtype: int64

# %%
# 고가와 저가의 중간 가격 구하기
high_prices = data['High']
low_prices = data['Low']
mid_prices = (high_prices + low_prices) / 2

mid_prices.shape
# Out:
# (1222,)

# %% [markdown]
# # **Visualize time series data**

# %%
# 그래프로 시각화 해보기
sns.set_style('whitegrid')
plt.figure(figsize=(15, 5))
plt.plot(mid_prices, c = 'g')
plt.title("Naver Corporation Stock Prices for 5 years", size = 15, y = 1.02)
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# # **Create Sequence**
# - Sequence Size = 50 + 1
# - 첫 번째 sequence는 50일 치의 값으로 그 다음 날의 값을 예측한다.
# - 그리고 두 번째 window는 하루 씩 밀려서 첫 날의 그 다음 날부터 50일치의 값으로 그 다음 날의 값을 예측한다.
# - 이러한 과정을 반복한다.

# %%
n_steps = 50 # time step = 50 
sequence_length = n_steps + 1 # 총 window size

# 리스트 생성
series = [] 

# result 리스트는 index 별로 51일치의 data가 들어감. 총 길이는 전체에서 51일을 뺀 값
for index in range(len(mid_prices) - sequence_length):
    series.append(mid_prices[index:index + sequence_length])

# %%
len(series[0])
# Out:
# 51

# %%
len(series)
# Out:
# 1171

# %% [markdown]
# # **Normalize Data**

# %%
normalized_data = []
window_mean = []
window_std = []

# Z-Score Normalization
for window in series:
    normalized_window = [((p - np.mean(window))/np.std(window)) for p in window]
    normalized_data.append(normalized_window) 
    window_mean.append(np.mean(window))
    window_std.append(np.std(window))

# 여기서 result는 Z-Score Normalization 되어진 dataset
series = np.array(normalized_data)

# %% [markdown]
# # **Train Valid Test split**

# %%
# 전체를 7:2:1 으로 분할
row1 = int(round(series.shape[0] * 0.7))
row2 = int(round(series.shape[0] * 0.2))
print(row1, row2, len(series) - (row1+row2))
# Out:
# 820 234 117

# %%
# train, valid, test 분할
X_train, y_train = series[:row1, :n_steps], series[:row1, -1]
X_valid, y_valid = series[row1:row1+row2, :n_steps], series[row1:row1+row2, -1]
X_test, y_test = series[row1+row2:, :n_steps], series[row1+row2:, -1]

# %%
X_train.shape, y_train.shape
# Out:
# ((820, 50), (820,))

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_valid = X_valid.reshape(X_valid.shape[0], X_valid.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

y_train = y_train.reshape(y_train.shape[0], 1)
y_valid = y_valid.reshape(y_valid.shape[0], 1)
y_test = y_test.reshape(y_test.shape[0], 1)

X_train.shape, y_train.shape
# Out:
# ((820, 50, 1), (820, 1))

# %% [markdown]
# - 학습데이터: 배치 사이즈 = 820, 타입 스텝 수 = 50, 단변량 값

# %% [markdown]
# # **Build a Model**

# %%
model = Sequential()

model.add(LSTM(50, return_sequences=True, input_shape=(50, 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(1))

model.compile(loss='mse', optimizer='adam')

model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_59 (LSTM)               (None, 50, 50)            10400
# _________________________________________________________________
# lstm_60 (LSTM)               (None, 50, 50)            20200
# _________________________________________________________________
# lstm_61 (LSTM)               (None, 50, 50)            20200
# _________________________________________________________________
# lstm_62 (LSTM)               (None, 50, 50)            20200
# _________________________________________________________________
# lstm_63 (LSTM)               (None, 50, 50)            20200
# _________________________________________________________________
# lstm_64 (LSTM)               (None, 50)                20200
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 111,451
# Trainable params: 111,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
# LR 콜백함수
from keras.callbacks import ReduceLROnPlateau

reduceLR = ReduceLROnPlateau(monitor='val_loss', patience=3, verbose=1, factor=0.1)

# %% [markdown]
# # **Training**

# %%
model.fit(X_train, y_train, 
          epochs=30,
          validation_data=(X_valid, y_valid),
          callbacks=[reduceLR])
# Out:
# Epoch 1/30
# 26/26 [==============================] - 15s 233ms/step - loss: 1.4787 - val_loss: 0.5962
# Epoch 2/30
# 26/26 [==============================] - 4s 146ms/step - loss: 0.7034 - val_loss: 0.4917
# Epoch 3/30
# 26/26 [==============================] - 4s 147ms/step - loss: 0.5735 - val_loss: 0.4307
# Epoch 4/30
# 26/26 [==============================] - 4s 145ms/step - loss: 0.4222 - val_loss: 0.4054
# Epoch 5/30
# 26/26 [==============================] - 4s 147ms/step - loss: 0.3604 - val_loss: 0.2882
# Epoch 6/30
# 26/26 [==============================] - 4s 149ms/step - loss: 0.3190 - val_loss: 0.4341
# Epoch 7/30
# 26/26 [==============================] - 4s 148ms/step - loss: 0.3820 - val_loss: 0.2874
# Epoch 8/30
# 26/26 [==============================] - 4s 150ms/step - loss: 0.3080 - val_loss: 0.2733
# Epoch 9/30
# 26/26 [==============================] - 4s 150ms/step - loss: 0.3089 - val_loss: 0.2387
# Epoch 10/30
# 26/26 [==============================] - 4s 149ms/step - loss: 0.2853 - val_loss: 0.2405
# Epoch 11/30
# 26/26 [==============================] - 4s 149ms/step - loss: 0.3314 - val_loss: 0.2004
# Epoch 12/30
# 26/26 [==============================] - 4s 147ms/step - loss: 0.2646 - val_loss: 0.1986
# Epoch 13/30
# 26/26 [==============================] - 4s 150ms/step - loss: 0.2475 - val_loss: 0.2758
# Epoch 14/30
# 26/26 [==============================] - 4s 151ms/step - loss: 0.2959 - val_loss: 0.1885
# Epoch 15/30
# 26/26 [==============================] - 4s 150ms/step - loss: 0.2200 - val_loss: 0.1951
# Epoch 16/30
# 26/26 [==============================] - 4s 149ms/step - loss: 0.2465 - val_loss: 0.1757
# Epoch 17/30
# 26/26 [==============================] - 4s 153ms/step - loss: 0.2407 - val_loss: 0.2386
# Epoch 18/30
# 26/26 [==============================] - 4s 153ms/step - loss: 0.2220 - val_loss: 0.2066
# Epoch 19/30
# 26/26 [==============================] - 4s 150ms/step - loss: 0.2061 - val_loss: 0.1708
# Epoch 20/30
# 26/26 [==============================] - 4s 150ms/step - loss: 0.1792 - val_loss: 0.3005
# Epoch 21/30
# 26/26 [==============================] - 4s 153ms/step - loss: 0.1843 - val_loss: 0.2320
# Epoch 22/30
# 26/26 [==============================] - 4s 155ms/step - loss: 0.2176 - val_loss: 0.2866
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 23/30
# 26/26 [==============================] - 4s 152ms/step - loss: 0.2344 - val_loss: 0.2076
# Epoch 24/30
# 26/26 [==============================] - 4s 151ms/step - loss: 0.1779 - val_loss: 0.1602
# Epoch 25/30
# 26/26 [==============================] - 4s 157ms/step - loss: 0.1513 - val_loss: 0.1587
# Epoch 26/30
# 26/26 [==============================] - 4s 155ms/step - loss: 0.1581 - val_loss: 0.1566
# Epoch 27/30
# 26/26 [==============================] - 4s 158ms/step - loss: 0.1495 - val_loss: 0.1566
# Epoch 28/30
# 26/26 [==============================] - 4s 155ms/step - loss: 0.1345 - val_loss: 0.1547
# Epoch 29/30
# 26/26 [==============================] - 4s 153ms/step - loss: 0.1383 - val_loss: 0.1598
# Epoch 30/30
# 26/26 [==============================] - 4s 154ms/step - loss: 0.1397 - val_loss: 0.1476

# %% [markdown]
# # **Prediction**

# %%
# 테스트 데이터 평가
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 35ms/step - loss: 0.1808
# 0.18078643083572388

# %%
# 예측값 구하기
predicted = model.predict(X_test)

# %%
# 시각화
sns.set_style('whitegrid')
fig = plt.figure(figsize=(15, 5))
plt.plot(y_test, label='True', c = 'g')
plt.plot(predicted, label='Prediction', c = 'r')
plt.title("Naver Corporation Stock Prices Prediction", size = 15, y = 1.02)
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend(fontsize = 15)
plt.show()
